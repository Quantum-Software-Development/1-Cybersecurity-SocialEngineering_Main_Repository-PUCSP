# %%
import requests
url='https://www.pucsp.br'

dados = requests.get(url)
print(dados.status_code)
dados.content

# %%
import requests
url='https://bloomberg-market-and-financial-news.p.rapidapi.com/market/get-movers'
dados = requests.get(url,params= {"id": 'nky:ind', "template": 'INDEX'}, headers= {
    'X-RapidAPI-Key': '7395c74fcdmshc55eca2cd2c9a8cp1901a1jsn9d93900b7993',
    'X-RapidAPI-Host': 'bloomberg-market-and-financial-news.p.rapidapi.com'
  })
dados.content

# %%
print(dados.json())
# Out:
# {'active': [{'securityType': 'Common Stock', 'symbol': '9432', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9432:jp', 'tickerName': '9432:JP', 'template': 'Stock', 'tinyName': 'NTT Inc', 'name': 'NTT Inc', 'watchlist': True, 'resourceId': '9432:JP', 'last': '151', 'netChange': '1', 'lastPriceTime': 1772778600, 'pctChange1M': '-1', 'yearHigh': '167', 'dayHigh': '152', 'volume': 191096900.0, 'yearLow': '135', 'dayLow': '150', 'pctChangeYTD': '-4', 'pctChange': '0.60'}, {'securityType': 'Common Stock', 'symbol': '9434', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9434:jp', 'tickerName': '9434:JP', 'template': 'Stock', 'tinyName': 'SoftBank Corp', 'name': 'SoftBank Corp', 'watchlist': True, 'resourceId': '9434:JP', 'last': '211', 'netChange': '1', 'lastPriceTime': 1772778600, 'pctChange1M': '-1', 'yearHigh': '248', 'dayHigh': '212', 'volume': 70140000.0, 'yearLow': '192', 'dayLow': '209', 'pctChangeYTD': '-2', 'pctChange': '0.53'}, {'securityType': 'Common Stock', 'symbol': '9501', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9501:jp', 'tickerName': '9501:JP', 'template': 'Stock', 'tinyName': 'Tokyo Electric Power Co Holdings Inc', 'name': 'Tokyo Electric Power Co Holdings Inc', 'watchlist': True, 'resourceId': '9501:JP', 'last': '643', 'netChange': '-7', 'lastPriceTime': 1772778600, 'pctChange1M': '1', 'yearHigh': '939', 'dayHigh': '658', 'volume': 51744900.0, 'yearLow': '360', 'dayLow': '629', 'pctChangeYTD': '-2', 'pctChange': '-1.14'}, {'securityType': 'Common Stock', 'symbol': '8306', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '8306:jp', 'tickerName': '8306:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi UFJ Financial Group Inc', 'name': 'Mitsubishi UFJ Financial Group Inc', 'watchlist': True, 'resourceId': '8306:JP', 'last': '2760', 'netChange': '24', 'lastPriceTime': 1772778600, 'pctChange1M': '-7', 'yearHigh': '3087', 'dayHigh': '2760', 'volume': 38919600.0, 'yearLow': '1310', 'dayLow': '2694', 'pctChangeYTD': '11', 'pctChange': '0.90'}, {'securityType': 'Common Stock', 'symbol': '9984', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9984:jp', 'tickerName': '9984:JP', 'template': 'Stock', 'tinyName': 'SoftBank Group Corp', 'name': 'SoftBank Group Corp', 'watchlist': True, 'resourceId': '9984:JP', 'last': '3926', 'netChange': '62', 'lastPriceTime': 1772778600, 'pctChange1M': '-8', 'yearHigh': '6924', 'dayHigh': '3953', 'volume': 37036500.0, 'yearLow': '1432', 'dayLow': '3780', 'pctChangeYTD': '-11', 'pctChange': '1.60'}, {'securityType': 'Common Stock', 'symbol': '4506', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4506:jp', 'tickerName': '4506:JP', 'template': 'Stock', 'tinyName': 'Sumitomo Pharma Co Ltd', 'name': 'Sumitomo Pharma Co Ltd', 'watchlist': True, 'resourceId': '4506:JP', 'last': '1920', 'netChange': '76', 'lastPriceTime': 1772778600, 'pctChange1M': '-15', 'yearHigh': '3288', 'dayHigh': '2028', 'volume': 32261200.0, 'yearLow': '500', 'dayLow': '1792', 'pctChangeYTD': '-17', 'pctChange': '4.09'}, {'securityType': 'Common Stock', 'symbol': '4689', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': ' ...

# %%
import json
dados_dict=json.loads(dados.content)
dados_dict.keys()
# Out:
# dict_keys(['active', 'laggards', 'leaders'])

# %%
print("ACTIVE:",dados_dict["active"])
print("LAGGARDS:",dados_dict["laggards"])
print("LEADERS:",dados_dict["leaders"])
# Out:
# ACTIVE: [{'securityType': 'Common Stock', 'symbol': '9432', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9432:jp', 'tickerName': '9432:JP', 'template': 'Stock', 'tinyName': 'Nippon Telegraph & Telephone Corp', 'name': 'Nippon Telegraph & Telephone Corp', 'watchlist': True, 'resourceId': '9432:JP', 'last': '147', 'netChange': '1', 'lastPriceTime': 1741588200, 'pctChange1M': '2', 'yearHigh': '185', 'dayHigh': '147', 'volume': 126331800.0, 'yearLow': '142', 'dayLow': '146', 'pctChangeYTD': '-7', 'lastPriceAllSessions': '147', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '0.89'}, {'securityType': 'Common Stock', 'symbol': '7011', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7011:jp', 'tickerName': '7011:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi Heavy Industries Ltd', 'name': 'Mitsubishi Heavy Industries Ltd', 'watchlist': True, 'resourceId': '7011:JP', 'last': '2345', 'netChange': '-144', 'lastPriceTime': 1741588200, 'pctChange1M': '8', 'yearHigh': '2597', 'dayHigh': '2526', 'volume': 78463100.0, 'yearLow': '1172', 'dayLow': '2322', 'pctChangeYTD': '5', 'lastPriceAllSessions': '2345', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-5.79'}, {'securityType': 'Common Stock', 'symbol': '9501', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9501:jp', 'tickerName': '9501:JP', 'template': 'Stock', 'tinyName': 'Tokyo Electric Power Co Holdings Inc', 'name': 'Tokyo Electric Power Co Holdings Inc', 'watchlist': True, 'resourceId': '9501:JP', 'last': '420', 'netChange': '15', 'lastPriceTime': 1741588200, 'pctChange1M': '5', 'yearHigh': '1114', 'dayHigh': '424', 'volume': 48977100.0, 'yearLow': '371', 'dayLow': '407', 'pctChangeYTD': '-11', 'lastPriceAllSessions': '420', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '3.80'}, {'securityType': 'Common Stock', 'symbol': '9434', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '9434:jp', 'tickerName': '9434:JP', 'template': 'Stock', 'tinyName': 'SoftBank Corp', 'name': 'SoftBank Corp', 'watchlist': True, 'resourceId': '9434:JP', 'last': '213', 'netChange': '-0', 'lastPriceTime': 1741588200, 'pctChange1M': '7', 'yearHigh': '218', 'dayHigh': '215', 'volume': 39823900.0, 'yearLow': '174', 'dayLow': '212', 'pctChangeYTD': '7', 'lastPriceAllSessions': '213', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-0.09'}, {'securityType': 'Common Stock', 'symbol': '8306', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '8306:jp', 'tickerName': '8306:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi UFJ Financial Group Inc', 'name': 'Mitsubishi UFJ Financial Group Inc', 'watchlist': True, 'resourceId': '8306:JP', 'last': '1920', 'netChange': '-2', 'lastPriceTime': 1741588200, 'pctChange1M': '1', 'yearHigh': '2039', 'dayHigh': '1938', 'volume': 33199000.0, 'yearLow': '1200', 'dayLow': '1918', 'pctChangeYTD': '4', 'lastPriceAllSessions': '1920', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-0.13'}, {'securityType': 'Common Stock', 'symbol': '7201', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7201:jp', 'tickerName': '7201:JP', 'template': 'Stock', 'tinyName': 'Nissan Motor Co Ltd', 'name': 'Nissan Motor Co Ltd', 'watchlist': True, 'resourceId': '7201:JP', 'last': '433', 'netChange': '-6', ' ...
# LAGGARDS: [{'securityType': 'Common Stock', 'symbol': '7453', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7453:jp', 'tickerName': '7453:JP', 'template': 'Stock', 'tinyName': 'Ryohin Keikaku Co Ltd', 'name': 'Ryohin Keikaku Co Ltd', 'watchlist': True, 'resourceId': '7453:JP', 'last': '3507', 'netChange': '-316', 'lastPriceTime': 1741588200, 'pctChange1M': '-12', 'yearHigh': '4180', 'dayHigh': '3798', 'volume': 6410700.0, 'yearLow': '2184', 'dayLow': '3503', 'pctChangeYTD': '-3', 'lastPriceAllSessions': '3507', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-8.27'}, {'securityType': 'Common Stock', 'symbol': '7011', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7011:jp', 'tickerName': '7011:JP', 'template': 'Stock', 'tinyName': 'Mitsubishi Heavy Industries Ltd', 'name': 'Mitsubishi Heavy Industries Ltd', 'watchlist': True, 'resourceId': '7011:JP', 'last': '2345', 'netChange': '-144', 'lastPriceTime': 1741588200, 'pctChange1M': '8', 'yearHigh': '2597', 'dayHigh': '2526', 'volume': 78463100.0, 'yearLow': '1172', 'dayLow': '2322', 'pctChangeYTD': '5', 'lastPriceAllSessions': '2345', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-5.79'}, {'securityType': 'Common Stock', 'symbol': '7013', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '7013:jp', 'tickerName': '7013:JP', 'template': 'Stock', 'tinyName': 'IHI Corp', 'name': 'IHI Corp', 'watchlist': True, 'resourceId': '7013:JP', 'last': '10275', 'netChange': '-560', 'lastPriceTime': 1741588200, 'pctChange1M': '11', 'yearHigh': '11990', 'dayHigh': '10975', 'volume': 9405200.0, 'yearLow': '3394', 'dayLow': '10215', 'pctChangeYTD': '10', 'lastPriceAllSessions': '10275', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-5.17'}, {'securityType': 'Common Stock', 'symbol': '3092', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '3092:jp', 'tickerName': '3092:JP', 'template': 'Stock', 'tinyName': 'ZOZO Inc', 'name': 'ZOZO Inc', 'watchlist': True, 'resourceId': '3092:JP', 'last': '4458', 'netChange': '-184', 'lastPriceTime': 1741588200, 'pctChange1M': '-10', 'yearHigh': '5604', 'dayHigh': '4639', 'volume': 1536900.0, 'yearLow': '3266', 'dayLow': '4419', 'pctChangeYTD': '-9', 'lastPriceAllSessions': '4458', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-3.96'}, {'securityType': 'Common Stock', 'symbol': '4519', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4519:jp', 'tickerName': '4519:JP', 'template': 'Stock', 'tinyName': 'Chugai Pharmaceutical Co Ltd', 'name': 'Chugai Pharmaceutical Co Ltd', 'watchlist': True, 'resourceId': '4519:JP', 'last': '6707', 'netChange': '-256', 'lastPriceTime': 1741588200, 'pctChange1M': '-4', 'yearHigh': '7979', 'dayHigh': '6967', 'volume': 2700800.0, 'yearLow': '4572', 'dayLow': '6666', 'pctChangeYTD': '-4', 'lastPriceAllSessions': '6707', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '-3.68'}, {'securityType': 'Common Stock', 'symbol': '5233', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '5233:jp', 'tickerName': '5233:JP', 'template': 'Stock', 'tinyName': 'Taiheiyo Cement Corp', 'name': 'Taiheiyo Cement Corp', 'watchlist': True, 'resourceId': '5233:JP', 'last': '3901', 'netChange': '-146', 'lastPriceTime': 1741588200, 'pctChange1M': '1', 'yearHigh':  ...
# LEADERS: [{'securityType': 'Common Stock', 'symbol': '6920', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '6920:jp', 'tickerName': '6920:JP', 'template': 'Stock', 'tinyName': 'Lasertec Corp', 'name': 'Lasertec Corp', 'watchlist': True, 'resourceId': '6920:JP', 'last': '15210', 'netChange': '1380', 'lastPriceTime': 1741588200, 'pctChange1M': '-0', 'yearHigh': '45500', 'dayHigh': '15210', 'volume': 13756200.0, 'yearLow': '12745', 'dayLow': '13820', 'pctChangeYTD': '0', 'lastPriceAllSessions': '15210', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '9.98'}, {'securityType': 'Common Stock', 'symbol': '6273', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '6273:jp', 'tickerName': '6273:JP', 'template': 'Stock', 'tinyName': 'SMC Corp', 'name': 'SMC Corp', 'watchlist': True, 'resourceId': '6273:JP', 'last': '58750', 'netChange': '3750', 'lastPriceTime': 1741588200, 'pctChange1M': '3', 'yearHigh': '90700', 'dayHigh': '58760', 'volume': 380400.0, 'yearLow': '53100', 'dayLow': '55760', 'pctChangeYTD': '-6', 'lastPriceAllSessions': '58750', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '6.82'}, {'baseName': 'Japan', 'securityType': 'Common Stock', 'symbol': '4661', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4661:jp', 'tickerName': '4661:JP', 'template': 'Stock', 'tinyName': 'Oriental Land Co Ltd/Japan', 'name': 'Oriental Land Co Ltd/Japan', 'watchlist': True, 'resourceId': '4661:JP', 'last': '3277', 'netChange': '172', 'lastPriceTime': 1741588200, 'pctChange1M': '0', 'yearHigh': '5094', 'dayHigh': '3298', 'volume': 12513700.0, 'yearLow': '3015', 'dayLow': '3105', 'pctChangeYTD': '-4', 'lastPriceAllSessions': '3277', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '5.54'}, {'securityType': 'Common Stock', 'symbol': '5801', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '5801:jp', 'tickerName': '5801:JP', 'template': 'Stock', 'tinyName': 'Furukawa Electric Co Ltd', 'name': 'Furukawa Electric Co Ltd', 'watchlist': True, 'resourceId': '5801:JP', 'last': '5835', 'netChange': '300', 'lastPriceTime': 1741588200, 'pctChange1M': '-23', 'yearHigh': '8304', 'dayHigh': '5865', 'volume': 5411500.0, 'yearLow': '2874', 'dayLow': '5502', 'pctChangeYTD': '-13', 'lastPriceAllSessions': '5835', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '5.42'}, {'securityType': 'Common Stock', 'symbol': '4324', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '4324:jp', 'tickerName': '4324:JP', 'template': 'Stock', 'tinyName': 'Dentsu Group Inc', 'name': 'Dentsu Group Inc', 'watchlist': True, 'resourceId': '4324:JP', 'last': '3461', 'netChange': '176', 'lastPriceTime': 1741588200, 'pctChange1M': '-1', 'yearHigh': '4910', 'dayHigh': '3495', 'volume': 2235500.0, 'yearLow': '3039', 'dayLow': '3308', 'pctChangeYTD': '-9', 'lastPriceAllSessions': '3461', 'lastPriceTimeAllSessions': 1741588200, 'pctChange': '5.36'}, {'securityType': 'Common Stock', 'symbol': '3436', 'exchange': 'Tokyo', 'country': 'Japan', 'currency': 'JPY', 'resourceType': 'Company', 'fundamentalDataCurrency': 'JPY', 'resourceSubtype': 'Public', 'region': 'APAC', 'ticker': '3436:jp', 'tickerName': '3436:JP', 'template': 'Stock', 'tinyName': 'SUMCO Corp', 'name': 'SUMCO Corp', 'watchlist': True, 'resourceId': '3436:JP', 'last': '1172', 'netChange': '44', 'lastPriceTime': 1741588200, 'pctChange1M': '-5', 'yearHigh': '2684', 'dayHigh': '1 ...

# %%
import pandas as pd
df_active=pd.DataFrame(dados_dict["active"])
df_active
# Out:
#    securityType symbol exchange country currency resourceType  \
# 0  Common Stock   9432    Tokyo   Japan      JPY      Company
# 1  Common Stock   9434    Tokyo   Japan      JPY      Company
# 2  Common Stock   9501    Tokyo   Japan      JPY      Company
# 3  Common Stock   8306    Tokyo   Japan      JPY      Company
# 4  Common Stock   9984    Tokyo   Japan      JPY      Company
# 5  Common Stock   4506    Tokyo   Japan      JPY      Company
# 6  Common Stock   4689    Tokyo   Japan      JPY      Company
# 7  Common Stock   7201    Tokyo   Japan      JPY      Company
# 8  Common Stock   5401    Tokyo   Japan      JPY      Company
# 9  Common Stock   4755    Tokyo   Japan      JPY      Company
#
#   fundamentalDataCurrency resourceSubtype region   ticker  ... netChange  \
# 0                     JPY          Public   APAC  9432:jp  ...         1
# 1                     JPY          Public   APAC  9434:jp  ...         1
# 2                     JPY          Public   APAC  9501:jp  ...        -7
# 3                     JPY          Public   APAC  8306:jp  ...        24
# 4                     JPY          Public   APAC  9984:jp  ...        62
# 5                     JPY          Public   APAC  4506:jp  ...        76
# 6                     JPY          Public   APAC  4689:jp  ...        21
# 7                     JPY          Public   APAC  7201:jp  ...        12
# 8                     JPY          Public   APAC  5401:jp  ...         4
# 9                     JPY          Public   APAC  4755:jp  ...        22
#
#   lastPriceTime pctChange1M yearHigh  dayHigh       volume yearLow dayLow  \
# 0    1772778600          -1      167      152  191096900.0     135    150
# 1    1772778600          -1      248      212   70140000.0     192    209
# 2    1772778600           1      939      658   51744900.0     360    629
# 3    1772778600          -7     3087     2760   38919600.0    1310   2694
# 4    1772778600          -8     6924     3953   37036500.0    1432   3780
# 5    1772778600         -15     3288     2028   32261200.0     500   1792
# 6    1772778600          -7      572      394   30669600.0     365    377
# 7    1772778600          -4      466      387   29749100.0     299    374
# 8    1772778600         -10      704      610   27624900.0     530    595
# 9    1772778600         -15     1068      822   23854300.0     695    785
#
#    pctChangeYTD pctChange
# 0            -4      0.60
# 1            -2      0.53
# 2            -2     -1.14
# 3            11      0.90
# 4           -11      1.60
# 5           -17      4.09
# 6            -6      5.58
# 7            -1      3.35
# 8            -6      0.65
# 9           -20      2.83
#
# [10 rows x 27 columns]

# %%
print(df_active.pctChange[0]+2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1090/2500357217.py in <cell line: 0>()
# ----> 1 print(df_active.pctChange[0]+2)
#
# TypeError: can only concatenate str (not "int") to str

# %%
float(df_active.pctChange[0])
pctChangeFloat=[]
for i in range(len(df_active.pctChange)):
  pctChangeFloat.append(float(df_active.pctChange[i]))

df_active["pct"]=pctChangeFloat
df_active["pct"]
print(df_active.pct[0]+2)
# Out:
# 2.6

# %%
import matplotlib.pyplot as plt
eixoX=df_active["symbol"]
eixoY=df_active["pct"]
plt.figure(figsize=(7,5))
plt.bar(eixoX,eixoY)
plt.show()

# %%
import requests
url='https://bb-finance.p.rapidapi.com/market/get-cross-currencies'
dados = requests.get(url,params= {"id": 'brl,cad,eur,usd'}, headers= {
    'X-RapidAPI-Key': '7395c74fcdmshc55eca2cd2c9a8cp1901a1jsn9d93900b7993',
     'X-RapidAPI-Host': 'bb-finance.p.rapidapi.com'
  })
dados.content
# Out:
# b'{"result":{"USDEUR:cur":{"baseName":"EURO","securityType":"CROSS","symbol":"USDEUR","country":"Europe","currency":"EUR","resourceType":"Currency","resourceSubtype":"Cross","region":"EMEA","ticker":"usdeur:cur","tickerName":"USDEUR:CUR","template":"Currency","tinyName":"USD-EUR","name":"USDEUR Spot Exchange Rate - Price of 1 USD in EUR","watchlist":true,"resourceId":"USDEUR:CUR","last":"0.8654","netChange":"0.0047","lastPriceTime":1773005726,"yearHigh":"0.9317","dayHigh":"0.8661","yearLow":"0.8277","sourceCurrency":"USD","dayLow":"0.8647","pctChange":"0.55"},"EURUSD:cur":{"baseName":"US DOLLAR","securityType":"CROSS","symbol":"EURUSD","country":"United States","currency":"USD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"eurusd:cur","tickerName":"EURUSD:CUR","template":"Currency","tinyName":"EUR-USD","name":"EURUSD Spot Exchange Rate - Price of 1 EUR in USD","watchlist":true,"resourceId":"EURUSD:CUR","last":"1.1555","netChange":"-0.0063","lastPriceTime":1773005704,"yearHigh":"1.2081","dayHigh":"1.1565","yearLow":"1.0733","sourceCurrency":"EUR","dayLow":"1.1546","pctChange":"-0.54"},"USDCAD:cur":{"baseName":"CANADIAN DOLLAR","securityType":"CROSS","symbol":"USDCAD","country":"Canada","currency":"CAD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"usdcad:cur","tickerName":"USDCAD:CUR","template":"Currency","tinyName":"USD-CAD","name":"USDCAD Spot Exchange Rate - Price of 1 USD in CAD","watchlist":true,"resourceId":"USDCAD:CUR","last":"1.3604","netChange":"0.0036","lastPriceTime":1773005799,"yearHigh":"1.4521","dayHigh":"1.3605","yearLow":"1.3482","sourceCurrency":"USD","dayLow":"1.3599","pctChange":"0.27"},"CADUSD:cur":{"baseName":"US DOLLAR","securityType":"CROSS","symbol":"CADUSD","country":"United States","currency":"USD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"cadusd:cur","tickerName":"CADUSD:CUR","template":"Currency","tinyName":"CAD-USD","name":"CADUSD Spot Exchange Rate - Price of 1 CAD in USD","watchlist":true,"resourceId":"CADUSD:CUR","last":"0.7351","netChange":"-0.0019","lastPriceTime":1773005787,"yearHigh":"0.7417","dayHigh":"0.7353","yearLow":"0.6887","sourceCurrency":"CAD","dayLow":"0.7350","pctChange":"-0.26"},"USDBRL:cur":{"baseName":"BRAZIL REAL","securityType":"CROSS","symbol":"USDBRL","country":"Brazil","currency":"BRL","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"usdbrl:cur","tickerName":"USDBRL:CUR","template":"Currency","tinyName":"USD-BRL","name":"USDBRL Spot Exchange Rate - Price of 1 USD in BRL","watchlist":true,"resourceId":"USDBRL:CUR","last":"5.2381","netChange":"-0.0257","lastPriceTime":1772830739,"yearHigh":"6.0962","yearLow":"5.1160","sourceCurrency":"USD","pctChange":"-0.49"},"BRLUSD:cur":{"baseName":"US DOLLAR","securityType":"CROSS","symbol":"BRLUSD","country":"United States","currency":"USD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"brlusd:cur","tickerName":"BRLUSD:CUR","template":"Currency","tinyName":"BRL-USD","name":"BRLUSD Spot Exchange Rate - Price of 1 BRL in USD","watchlist":true,"resourceId":"BRLUSD:CUR","last":"0.1909","netChange":"0.0009","lastPriceTime":1772830739,"yearHigh":"0.1955","yearLow":"0.1640","sourceCurrency":"BRL","pctChange":"0.47"},"EURCAD:cur":{"baseName":"CANADIAN DOLLAR","securityType":"CROSS","symbol":"EURCAD","country":"Canada","currency":"CAD","resourceType":"Currency","resourceSubtype":"Cross","region":"AMERICAS","ticker":"eurcad:cur","tickerName":"EURCAD:CUR","template":"Currency","tinyName":"EUR-CAD","name":"EURCAD Spot Exchange Rate - Price of 1 EUR in CAD","watchlist":true,"resourceId":"EURCAD:CUR","last":"1.57089","netChange":"-0.00534","lastPriceTime":1773003640,"yearHigh":"1.64676","dayHigh":"1.57307","yearLow":"1.53321","sourceCurrency":"EUR","dayLow":"1.57050","pctChange":"-0.34"},"CADEUR:cur":{"baseName":"EURO","securityType":"CROSS","symbol":"CADEUR","country":"Eur ...

# %%
import json
dados_dict=json.loads(dados.content)
dados_dict.keys()
# Out:
# dict_keys(['result'])

# %%
print(dados_dict["result"])
# Out:
# {'USDEUR:cur': {'baseName': 'EURO', 'securityType': 'CROSS', 'symbol': 'USDEUR', 'country': 'Europe', 'currency': 'EUR', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'EMEA', 'ticker': 'usdeur:cur', 'tickerName': 'USDEUR:CUR', 'template': 'Currency', 'tinyName': 'USD-EUR', 'name': 'USDEUR Spot Exchange Rate - Price of 1 USD in EUR', 'watchlist': True, 'resourceId': 'USDEUR:CUR', 'last': '0.8654', 'netChange': '0.0047', 'lastPriceTime': 1773005726, 'yearHigh': '0.9317', 'dayHigh': '0.8661', 'yearLow': '0.8277', 'sourceCurrency': 'USD', 'dayLow': '0.8647', 'pctChange': '0.55'}, 'EURUSD:cur': {'baseName': 'US DOLLAR', 'securityType': 'CROSS', 'symbol': 'EURUSD', 'country': 'United States', 'currency': 'USD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'eurusd:cur', 'tickerName': 'EURUSD:CUR', 'template': 'Currency', 'tinyName': 'EUR-USD', 'name': 'EURUSD Spot Exchange Rate - Price of 1 EUR in USD', 'watchlist': True, 'resourceId': 'EURUSD:CUR', 'last': '1.1555', 'netChange': '-0.0063', 'lastPriceTime': 1773005704, 'yearHigh': '1.2081', 'dayHigh': '1.1565', 'yearLow': '1.0733', 'sourceCurrency': 'EUR', 'dayLow': '1.1546', 'pctChange': '-0.54'}, 'USDCAD:cur': {'baseName': 'CANADIAN DOLLAR', 'securityType': 'CROSS', 'symbol': 'USDCAD', 'country': 'Canada', 'currency': 'CAD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'usdcad:cur', 'tickerName': 'USDCAD:CUR', 'template': 'Currency', 'tinyName': 'USD-CAD', 'name': 'USDCAD Spot Exchange Rate - Price of 1 USD in CAD', 'watchlist': True, 'resourceId': 'USDCAD:CUR', 'last': '1.3604', 'netChange': '0.0036', 'lastPriceTime': 1773005799, 'yearHigh': '1.4521', 'dayHigh': '1.3605', 'yearLow': '1.3482', 'sourceCurrency': 'USD', 'dayLow': '1.3599', 'pctChange': '0.27'}, 'CADUSD:cur': {'baseName': 'US DOLLAR', 'securityType': 'CROSS', 'symbol': 'CADUSD', 'country': 'United States', 'currency': 'USD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'cadusd:cur', 'tickerName': 'CADUSD:CUR', 'template': 'Currency', 'tinyName': 'CAD-USD', 'name': 'CADUSD Spot Exchange Rate - Price of 1 CAD in USD', 'watchlist': True, 'resourceId': 'CADUSD:CUR', 'last': '0.7351', 'netChange': '-0.0019', 'lastPriceTime': 1773005787, 'yearHigh': '0.7417', 'dayHigh': '0.7353', 'yearLow': '0.6887', 'sourceCurrency': 'CAD', 'dayLow': '0.7350', 'pctChange': '-0.26'}, 'USDBRL:cur': {'baseName': 'BRAZIL REAL', 'securityType': 'CROSS', 'symbol': 'USDBRL', 'country': 'Brazil', 'currency': 'BRL', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'usdbrl:cur', 'tickerName': 'USDBRL:CUR', 'template': 'Currency', 'tinyName': 'USD-BRL', 'name': 'USDBRL Spot Exchange Rate - Price of 1 USD in BRL', 'watchlist': True, 'resourceId': 'USDBRL:CUR', 'last': '5.2381', 'netChange': '-0.0257', 'lastPriceTime': 1772830739, 'yearHigh': '6.0962', 'yearLow': '5.1160', 'sourceCurrency': 'USD', 'pctChange': '-0.49'}, 'BRLUSD:cur': {'baseName': 'US DOLLAR', 'securityType': 'CROSS', 'symbol': 'BRLUSD', 'country': 'United States', 'currency': 'USD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'brlusd:cur', 'tickerName': 'BRLUSD:CUR', 'template': 'Currency', 'tinyName': 'BRL-USD', 'name': 'BRLUSD Spot Exchange Rate - Price of 1 BRL in USD', 'watchlist': True, 'resourceId': 'BRLUSD:CUR', 'last': '0.1909', 'netChange': '0.0009', 'lastPriceTime': 1772830739, 'yearHigh': '0.1955', 'yearLow': '0.1640', 'sourceCurrency': 'BRL', 'pctChange': '0.47'}, 'EURCAD:cur': {'baseName': 'CANADIAN DOLLAR', 'securityType': 'CROSS', 'symbol': 'EURCAD', 'country': 'Canada', 'currency': 'CAD', 'resourceType': 'Currency', 'resourceSubtype': 'Cross', 'region': 'AMERICAS', 'ticker': 'eurcad:cur', 'tickerName': 'EURCAD:CUR', 'template': 'Currency', 'tinyName': 'EUR-CAD', 'name': 'EURCAD Spot Exchange Rate - Price of 1 EUR in CAD', 'watchlist': True, ' ...

# %%
import pandas as pd
df_curr=pd.DataFrame(dados_dict["result"])
print(df_curr.keys())
df_curr
# Out:
# Index(['USDEUR:cur', 'EURUSD:cur', 'USDCAD:cur', 'CADUSD:cur', 'USDBRL:cur',
#        'BRLUSD:cur', 'EURCAD:cur', 'CADEUR:cur', 'EURBRL:cur', 'BRLEUR:cur',
#        'BRLCAD:cur'],
#       dtype='object')
#                                                         USDEUR:cur  \
# baseName                                                      EURO
# securityType                                                 CROSS
# symbol                                                      USDEUR
# country                                                     Europe
# currency                                                       EUR
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                        EMEA
# ticker                                                  usdeur:cur
# tickerName                                              USDEUR:CUR
# template                                                  Currency
# tinyName                                                   USD-EUR
# name             USDEUR Spot Exchange Rate - Price of 1 USD in EUR
# watchlist                                                     True
# resourceId                                              USDEUR:CUR
# last                                                        0.8654
# netChange                                                   0.0047
# lastPriceTime                                           1773005726
# yearHigh                                                    0.9317
# dayHigh                                                     0.8661
# yearLow                                                     0.8277
# sourceCurrency                                                 USD
# dayLow                                                      0.8647
# pctChange                                                     0.55
#
#                                                         EURUSD:cur  \
# baseName                                                 US DOLLAR
# securityType                                                 CROSS
# symbol                                                      EURUSD
# country                                              United States
# currency                                                       USD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  eurusd:cur
# tickerName                                              EURUSD:CUR
# template                                                  Currency
# tinyName                                                   EUR-USD
# name             EURUSD Spot Exchange Rate - Price of 1 EUR in USD
# watchlist                                                     True
# resourceId                                              EURUSD:CUR
# last                                                        1.1555
# netChange                                                  -0.0063
# lastPriceTime                                           1773005704
# yearHigh                                                    1.2081
# dayHigh                                                     1.1565
# yearLow                                                     1.0733
# sourceCurrency                                                 EUR
# dayLow                                                      1.1546
# pctChange                                                    -0.54
#
#                                                         USDCAD:cur  \
# baseName                                           CANADIAN DOLLAR
# securityType                                                 CROSS
# symbol                                                      USDCAD
# country                                                     Canada
# currency                                                       CAD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  usdcad:cur
# tickerName                                              USDCAD:CUR
# template                                                  Currency
# tinyName                                                   USD-CAD
# name             USDCAD Spot Exchange Rate - Price of 1 USD in CAD
# watchlist                                                     True
# resourceId                                              USDCAD:CUR
# last                                                        1.3604
# netChange                                                   0.0036
# lastPriceTime                                           1773005799
# yearHigh                                                    1.4521
# dayHigh                                                     1.3605
# yearLow                                                     1.3482
# sourceCurrency                                                 USD
# dayLow                                                      1.3599
# pctChange                                                     0.27
#
#                                                         CADUSD:cur  \
# baseName                                                 US DOLLAR
# securityType                                                 CROSS
# symbol                                                      CADUSD
# country                                              United States
# currency                                                       USD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  cadusd:cur
# tickerName                                              CADUSD:CUR
# template                                                  Currency
# tinyName                                                   CAD-USD
# name             CADUSD Spot Exchange Rate - Price of 1 CAD in USD
# watchlist                                                     True
# resourceId                                              CADUSD:CUR
# last                                                        0.7351
# netChange                                                  -0.0019
# lastPriceTime                                           1773005787
# yearHigh                                                    0.7417
# dayHigh                                                     0.7353
# yearLow                                                     0.6887
# sourceCurrency                                                 CAD
# dayLow                                                      0.7350
# pctChange                                                    -0.26
#
#                                                         USDBRL:cur  \
# baseName                                               BRAZIL REAL
# securityType                                                 CROSS
# symbol                                                      USDBRL
# country                                                     Brazil
# currency                                                       BRL
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  usdbrl:cur
# tickerName                                              USDBRL:CUR
# template                                                  Currency
# tinyName                                                   USD-BRL
# name             USDBRL Spot Exchange Rate - Price of 1 USD in BRL
# watchlist                                                     True
# resourceId                                              USDBRL:CUR
# last                                                        5.2381
# netChange                                                  -0.0257
# lastPriceTime                                           1772830739
# yearHigh                                                    6.0962
# dayHigh                                                        NaN
# yearLow                                                     5.1160
# sourceCurrency                                                 USD
# dayLow                                                         NaN
# pctChange                                                    -0.49
#
#                                                         BRLUSD:cur  \
# baseName                                                 US DOLLAR
# securityType                                                 CROSS
# symbol                                                      BRLUSD
# country                                              United States
# currency                                                       USD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  brlusd:cur
# tickerName                                              BRLUSD:CUR
# template                                                  Currency
# tinyName                                                   BRL-USD
# name             BRLUSD Spot Exchange Rate - Price of 1 BRL in USD
# watchlist                                                     True
# resourceId                                              BRLUSD:CUR
# last                                                        0.1909
# netChange                                                   0.0009
# lastPriceTime                                           1772830739
# yearHigh                                                    0.1955
# dayHigh                                                        NaN
# yearLow                                                     0.1640
# sourceCurrency                                                 BRL
# dayLow                                                         NaN
# pctChange                                                     0.47
#
#                                                         EURCAD:cur  \
# baseName                                           CANADIAN DOLLAR
# securityType                                                 CROSS
# symbol                                                      EURCAD
# country                                                     Canada
# currency                                                       CAD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  eurcad:cur
# tickerName                                              EURCAD:CUR
# template                                                  Currency
# tinyName                                                   EUR-CAD
# name             EURCAD Spot Exchange Rate - Price of 1 EUR in CAD
# watchlist                                                     True
# resourceId                                              EURCAD:CUR
# last                                                       1.57089
# netChange                                                 -0.00534
# lastPriceTime                                           1773003640
# yearHigh                                                   1.64676
# dayHigh                                                    1.57307
# yearLow                                                    1.53321
# sourceCurrency                                                 EUR
# dayLow                                                     1.57050
# pctChange                                                    -0.34
#
#                                                         CADEUR:cur  \
# baseName                                                      EURO
# securityType                                                 CROSS
# symbol                                                      CADEUR
# country                                                     Europe
# currency                                                       EUR
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                        EMEA
# ticker                                                  cadeur:cur
# tickerName                                              CADEUR:CUR
# template                                                  Currency
# tinyName                                                   CAD-EUR
# name             CADEUR Spot Exchange Rate - Price of 1 CAD in EUR
# watchlist                                                     True
# resourceId                                              CADEUR:CUR
# last                                                        0.6366
# netChange                                                   0.0022
# lastPriceTime                                           1773003627
# yearHigh                                                    0.6522
# dayHigh                                                     0.6367
# yearLow                                                     0.6072
# sourceCurrency                                                 CAD
# dayLow                                                      0.6356
# pctChange                                                     0.35
#
#                                                         EURBRL:cur  \
# baseName                                               BRAZIL REAL
# securityType                                                 CROSS
# symbol                                                      EURBRL
# country                                                     Brazil
# currency                                                       BRL
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  eurbrl:cur
# tickerName                                              EURBRL:CUR
# template                                                  Currency
# tinyName                                                   EUR-BRL
# name             EURBRL Spot Exchange Rate - Price of 1 EUR in BRL
# watchlist                                                     True
# resourceId                                              EURBRL:CUR
# last                                                        6.0798
# netChange                                                  -0.0266
# lastPriceTime                                           1772830739
# yearHigh                                                    6.7499
# dayHigh                                                        NaN
# yearLow                                                     6.0012
# sourceCurrency                                                 EUR
# dayLow                                                         NaN
# pctChange                                                    -0.44
#
#                                                         BRLEUR:cur  \
# baseName                                                      EURO
# securityType                                                 CROSS
# symbol                                                      BRLEUR
# country                                                     Europe
# currency                                                       EUR
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                        EMEA
# ticker                                                  brleur:cur
# tickerName                                              BRLEUR:CUR
# template                                                  Currency
# tinyName                                                   BRL-EUR
# name             BRLEUR Spot Exchange Rate - Price of 1 BRL in EUR
# watchlist                                                     True
# resourceId                                              BRLEUR:CUR
# last                                                       0.16449
# netChange                                                  0.00075
# lastPriceTime                                           1772830733
# yearHigh                                                   0.16627
# dayHigh                                                        NaN
# yearLow                                                    0.14818
# sourceCurrency                                                 BRL
# dayLow                                                         NaN
# pctChange                                                     0.46
#
#                                                         BRLCAD:cur
# baseName                                           CANADIAN DOLLAR
# securityType                                                 CROSS
# symbol                                                      BRLCAD
# country                                                     Canada
# currency                                                       CAD
# resourceType                                              Currency
# resourceSubtype                                              Cross
# region                                                    AMERICAS
# ticker                                                  brlcad:cur
# tickerName                                              BRLCAD:CUR
# template                                                  Currency
# tinyName                                                   BRL-CAD
# name             BRLCAD Spot Exchange Rate - Price of 1 BRL in CAD
# watchlist                                                     True
# resourceId                                              BRLCAD:CUR
# last                                                        0.2590
# netChange                                                  -0.0008
# lastPriceTime                                           1772834353
# yearHigh                                                    0.2675
# dayHigh                                                        NaN
# yearLow                                                     0.2323
# sourceCurrency                                                 BRL
# dayLow                                                         NaN
# pctChange                                                    -0.31

# %%
import pandas as pd
df_curr=pd.DataFrame(dados_dict["result"])
df_curr.keys()
float(df_curr["USDEUR:cur"]["last"])
for x in df_curr.keys():
  print(x,":",float(df_curr[x]["last"]))
vlr=[]
for x in df_curr.keys():
  vlr.append(float(df_curr[x]["last"]))
vlr
# Out:
# USDEUR:cur : 0.8654
# EURUSD:cur : 1.1555
# USDCAD:cur : 1.3604
# CADUSD:cur : 0.7351
# USDBRL:cur : 5.2381
# BRLUSD:cur : 0.1909
# EURCAD:cur : 1.57089
# CADEUR:cur : 0.6366
# EURBRL:cur : 6.0798
# BRLEUR:cur : 0.16449
# BRLCAD:cur : 0.259
# [0.8654,
#  1.1555,
#  1.3604,
#  0.7351,
#  5.2381,
#  0.1909,
#  1.57089,
#  0.6366,
#  6.0798,
#  0.16449,
#  0.259]

# %%
import matplotlib.pyplot as plt
eixoX=df_curr.keys()
eixoY=vlr
plt.figure(figsize=(14,8))
plt.bar(eixoX,eixoY)
plt.show()
